# %% [markdown]
# <a href="https://colab.research.google.com/github/NavyaC24/Neural-Networks/blob/master/MNIST_dataset_Classification_using_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
